# %% [markdown]
# # OpenAI Completions - optional
#
#
# Once you are configured, then you will be able to get completions for your text.

# %%
from pyrit.executor.attack import PromptSendingAttack
from pyrit.output import output_attack_async
from pyrit.prompt_target import OpenAICompletionTarget
from pyrit.setup import IN_MEMORY, initialize_pyrit_async

await initialize_pyrit_async(memory_db_type=IN_MEMORY)  # type: ignore

# Note that max_tokens will default to 16 for completions, so you may want to set the upper limit of allowed tokens for a longer response.
target = OpenAICompletionTarget(max_tokens=2048)

attack = PromptSendingAttack(objective_target=target)
result = await attack.execute_async(objective="Hello! Who are you?")  # type: ignore
await output_attack_async(result)
# Out:
# python-dotenv could not parse statement starting at line 19
# Found default environment files: ['./.pyrit/.env', './.pyrit/.env.local']
# Loaded environment file: ./.pyrit/.env
# Loaded environment file: ./.pyrit/.env.local
# No new upgrade operations detected.
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#                                   ❓ ATTACK RESULT: UNDETERMINED ❓
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#  Attack Summary
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📋 Basic Information
#     • Objective: Hello! Who are you?
#     • Attack Type: PromptSendingAttack
#     • Conversation ID: dff91aa8-7446-419a-9b81-63ba015dc159
#
#   ⚡ Execution Metrics
#     • Turns Executed: 1
#     • Execution Time: 13.10s
#
#   🎯 Outcome
#     • Status: ❓ UNDETERMINED
#     • Reason: No objective scorer configured
#
#  Conversation History with Objective Target
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🔹 Turn 1 - USER
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   Hello! Who are you?
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🔸 ASSISTANT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    How can I help you?"
#
#     I had to explain I did not have an appointment and how I found that they had already repaired my
#       mom's X2 last Monday.
#
#     "Where are you? Here or Call Toll Free?"
#
#     "In. GuangZhou"
#
#     "What is your address?'
#
#     "I'm in Dell Corporate Center, East 9th St., across from UPS. I'm driving there now."
#
#     "If you're going there now..that's fine, you can go there. They can take care of it."
#
#     "You do know that it has been diagnosed wrong for billing purposes right? It was already fixed?"
#
#     "I know, I know. Welcome. Welcome to come in."
#
#     Apparently, I did not know how much I should have spent my mom's money.
#
#     I arrived just in time before closing. While waiting for the repair agent to finish his
#       conversation with the customer, I went around to check if my other computer would work even with
#       the mother board out.
#
#     The repair representative then noticed my other computer. He told me that the price of an
#       equivalent for this Latitude X2 was $499 without the needed battery! I explained that I already
#       had one!
#
#     When the other customer was finished, the repair agent have me a quote of $195. “ You luckily are
#       here, She just goes her 2 years free"
#
#     $195 is reasonable compared with the $600 for a new one.
#
#     "By the time you configure the unit, it already takes more than 2 hours, and this spare part is
#       here, no need for back-order, you are just lucky it is here."
#
#     I quipped, "Speaks well for your stock management!"
#
#     The other customer then told me that she was also at the Sentosa Bridge earlier, standing by for
#       over 2 hours, just to get her new key- board and mouse. She was surprised to find out that I was
#       able to get my mother board repaired.
#
#     I could not get the repair that day because the agent had trouble hooking the machine up to the
#       outlet. At least the diode is now properly seating in its place.
#
#     Moral of the Test:
#
#     Know(god has already prepared it) and Trust(god has prepared the answer for me) that God is the
#       Giver of time and He will provide it at the proper time.
#
#     For those who have experienced hardships before, see the newer things now with new eyes. Do not
#       take anyone for granted, and also be prepared once you know the answer.
#
#     Believe beyond what you think you can accept.
#
#     Great is God!
#
#     God gave His one and Only Son so that any who believes in Him shall not perish but have eternal
#       life. Not because we deserve it, but it is out of His mercy that He gave.
#
#     The LORD loves righteousness and justice;     the earth is full of his unfailing love. Psalm 33:5
#
#     Images credits: images search on Google Search
#
#     posted by maryannld at 5:19 PM 1 comments links to this post
#
#     Wednesday, November 09, 2005
#
#     Ironic
#
#     I blame a metro card for my broken down computer! Eataceleibator! A metro card, meaning?
#
#     Cat
#
#     See that rumble strip on the right side? That's where I hit the Nissan, almost hitting the side of
#       the building where the patients are waiting for their turn to be treated! According to the
#       Nate's HITS' survey or what, I could have been wrong!
#
#     Piper
#
#     I had to ask for the impairment and I could not hear the answers for her first 3, in which I had
#       less time to conduct my full test. Than we have to have that "HPS" there to act as my cox of
#       time! Ridiculous of that, wouldn't you say so?
#
#     Dell Latitude X2
#     The mobo is burned out. How can I blame it if I don't have a spare battery?! Don't bet on your
#       mother board being in two pieces!
#     (picture coming soon!)
#
#     So what can I say?
#
#     Life is sweet! Blame it to God who gives me patience and love. I can only say at this time how
#       much I'm grateful for it. When this situation comes about, trust in God, He knows more than how
#       long it will take or to time us.
#
#     See you in a bit.
#
#     posted by maryannld at 2:54 PM 4 comments links to this post
#
#     Monday, November 07, 2005
#
#     Life in Retail
#
#     Some of the major reasons for return on the products insured by the consumer or the benefits that
#       should be given in a rehab plan are equipment attitude and habit.
#
#     The equipment attitude is the evaluation if the consumers is competent and knowledgeable of the
#       device itself and with the processes that the computer should do in general.
#
#     The first goal of the department of physical rehabilitation is to reeducate the consumer and to
#       fix and apply correct habits in using rehabilitant equipment like a computer, mobility/
#       balancing device, an electrically alterted mealtray or a power wheelchair.
#
#     To reinforce the habit of holding the fedora on top of the head during production is a negative
#       one while turning the hands inward instead of inwardly.
#
#     Basically, there should be proper training of the user(s) in any form or technique of handling any
#       equipment before letting it in their production stages.
#
#     The typical rehab plan has 2 hours allotted, 1 hour for the session itself, and the other 1 hour
#       for the insurance adjuster itself. If it is a portable device, the revertion process would have
#       to be handled so that the new producer(s) can use the full capabilities of its intended purpose
#       that is being compensated.
#
#     After all the adjustments of its relocation, it is verified that the capability of it will produce
#       and maximize its usefulness to achieve its intended goal achievability.
#
#     One of the factors to put in a rehab plan is the user(s) input and goal.
#
#     The treatment goals are specific and time bound.
#
#     The goal covers its specific capability to improve and achieve a certain action.
#
#     It should be measurable in numbers and should be toward a number generated by the activity to
#       which it was used for.
#
#     It should have a duration listed with the date to be attained.
#
#     The users should have the participation in the process so that the rehab plan to be approved will
#       result to a complete document with a stronger basis and stronger goals for the patient to
#       fulfill.
#
#     If the users complements redound to box 13 in the “subscribers comments” it gives a stronger
#       foothold for the info to be taken into consideration to further the process of the treatment
#       plan.
#
#     That's it for now. More info and details later on. Operation Mellow Yellow... coming soon...
#
#     posted by maryannld at 9:39 PM 0 comments links to this post
#
#     Sunday, November 06, 2005
#
#     Hunter 1 Team
#
#     I dunno, I just feel like being a commando here in the store!
#
#     posted by maryannld at 9:39 PM 2 comments links to this post
#
#     Friday, November 04, 2005
#
#     Number 10
#
#     Nine beats are passing in front of our gaze Look at that one. We know one’s family then Let me see
#       fifteen of a kind Bag u porpoise. We know ten. Gòng mì ài cà? That’s enough! Nièng zen tian.
#     What was for dinner?
#
#     Well, we tied our farewell event today for Bonom. It has been a great joy, not because I loved the
#       chicken dish yalling’an (好)but because it was sort of an ice breaker to the new crew added to
#       our department.
#
#     But alas, we were cunning when we realized that the event was supposed to end at 2245 hrs.,
#       getting a head start in the game of Ghost in the Graveyard. One by one, our Sorority Sisters got
#       zeroed out!
#
#     The suspense of what was in store for the game was in the air, some of us not knowing what to do
#       or where to go. We
#     eventually asked around sharing the information that they should stick around in the store!
#
#     With that, it was not too long, the store was silent, whitedoors and whitedesks, and here we are
#       wondering where are the ghosts?!
#
#     Time stood still and we saw the images of familiar adults hovering around the walls and shelves
#       around us!
#
#     Wow. We freaked out to the extreme! The first verse was on hurried feet moving to the ever-
#       forgotten chorus of “Ghost in the Graveyard.” It was a good exercise for burning calories after
#       all the adobo and rice!
#
#     It ended with a Kumpare Ko’s trophy that I got for the fastest elimination.
#
#     I found this to be fun despite it not being in the mood to be silly. After all, it’s not every
#       participant who usually receives a legitimate “thank you and good luck.”
#
#     Lainie, Lainie, Lainie... getting you out of Overtime in the Operations Department tomorrow at
#       UPS. With that...
#
#     Ching!
#
#     Adios
#
#     posted by maryannld at 9:39 PM 2 comments links to this post
#
#     Thursday, November 03, 2005
#
#     Trick or Treat
#
#     Somebody had popcorn for snack, and I sat down beside Skittlekiester who was on snackshift on his
#       desk in the golden room.
#     PSH!
#     Then all we could do is grin from ear to ear from the buttered popcorn mixed with the Jolly
#       Rancher he was eating. Then we reflected in our own terminal screen that it was not the same
#       smell. It was so semsem.
#     In a little while, Sinjin Plow and BJ joined the party.
#     Wow. Pcboy has been missing for a month or more. He’s usually the one who would sit by Winkydink
#       but he wasn’t with us this route.
#     We had some nipitang for the family that came for the Halloween party, then I went to the Sephora
#       Section of Macy's looking for Mr. You. I think I still can't afford that stuff. The fragrance is
#       nice but it will
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#                             Report generated at: 2026-05-21 18:20:48 UTC
