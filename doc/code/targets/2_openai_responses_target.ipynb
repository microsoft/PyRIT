# %% [markdown]
# # OpenAI Responses Target
#
# In this demo, we show an example of the `OpenAIResponseTarget`. [Responses](https://platform.openai.com/docs/api-reference/responses) is a newer protocol than chat completions and provides additional functionality with a somewhat modified API. The allowed input types include text, image, web search, file search, functions, reasoning, and computer use.
#
#
#
# ## OpenAI Configuration
#
# Like most targets, all `OpenAITarget`s need an `endpoint` and often also needs a `model` and a `key`. These can be passed into the constructor or configured with environment variables (or in .env).
#
# - endpoint: The API endpoint (`OPENAI_RESPONSES_ENDPOINT` environment variable). For OpenAI, these are just "https://api.openai.com/v1/responses".
# - auth: The API key for authentication (`OPENAI_RESPONSES_KEY` environment variable).
# - model_name: The model to use (`OPENAI_RESPONSES_MODEL` environment variable). For OpenAI, these are any available model name and are listed here: "https://platform.openai.com/docs/models".

# %%
import os

from pyrit.auth import get_azure_openai_auth
from pyrit.executor.attack import PromptSendingAttack
from pyrit.output import output_attack_async
from pyrit.prompt_target import OpenAIResponseTarget
from pyrit.setup import IN_MEMORY, initialize_pyrit_async

await initialize_pyrit_async(memory_db_type=IN_MEMORY)  # type: ignore

# For Azure OpenAI with Entra ID authentication (no API key needed, run `az login` first):
endpoint = os.environ["OPENAI_RESPONSES_ENDPOINT"]
target = OpenAIResponseTarget(
    endpoint=endpoint,
    api_key=get_azure_openai_auth(endpoint),
)

attack = PromptSendingAttack(objective_target=target)

result = await attack.execute_async(objective="Tell me a joke")  # type: ignore
await output_attack_async(result)
# Out:
# Auto-discovered plaintext environment file ./.pyrit/.env will be loaded. Azure Key Vault through env_akv_ref is more secure for shared or deployed secrets; use .env.local only for deliberate local overrides. To inspect a resolved AKV-only configuration from a source checkout, run `python -m build_scripts.export_akv_environment`; it writes ~/.pyrit/.env_akv.
# WARNING: Auto-discovered plaintext environment file ./.pyrit/.env will be loaded. Azure Key Vault through env_akv_ref is more secure for shared or deployed secrets; use .env.local only for deliberate local overrides. To inspect a resolved AKV-only configuration from a source checkout, run `python -m build_scripts.export_akv_environment`; it writes ~/.pyrit/.env_akv.
# Found default environment files: ['./.pyrit/.env', './.pyrit/.env.local']
# Loaded environment file: ./.pyrit/.env
# Loaded environment file: ./.pyrit/.env.local
# [pyrit:alembic] No new upgrade operations detected.
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#                                   ❓ ATTACK RESULT: UNDETERMINED ❓
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#  Attack Summary
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📋 Basic Information
#     • Objective: Tell me a joke
#     • Attack Type: PromptSendingAttack
#     • Conversation ID: b4d34111-84d9-42ac-87f2-77d266a1460c
#
#   ⚡ Execution Metrics
#     • Turns Executed: 1
#     • Execution Time: 10.82s
#
#   🎯 Outcome
#     • Status: ❓ UNDETERMINED
#     • Reason: No objective scorer configured
#
#  Conversation History with Objective Target
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🔹 Turn 1 - USER
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   Tell me a joke
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🔸 ASSISTANT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   Why don’t scientists trust atoms? Because they make up everything.
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#                             Report generated at: 2026-08-27 20:45:55 UTC

# %% [markdown]
# ## Reasoning Configuration
#
# Reasoning models (e.g., o1, o3, o4-mini, GPT-5) support a `reasoning` parameter that controls how much internal reasoning the model performs before responding. You can configure this with two parameters:
#
# - **`reasoning_effort`**: Controls the depth of reasoning. Accepts `"minimal"`, `"low"`, `"medium"`, or `"high"`. Lower effort favors speed and lower cost; higher effort favors thoroughness. The default (when not set) is typically `"medium"`.
# - **`reasoning_summary`**: Controls whether a summary of the model's internal reasoning is included in the response. Accepts `"auto"`, `"concise"`, or `"detailed"`. By default, no summary is included.
#
# For more information, see the [OpenAI reasoning guide](https://developers.openai.com/api/docs/guides/reasoning).

# %%
import os

from pyrit.auth import get_azure_openai_auth
from pyrit.executor.attack import PromptSendingAttack
from pyrit.prompt_target import OpenAIResponseTarget
from pyrit.setup import IN_MEMORY, initialize_pyrit_async

await initialize_pyrit_async(memory_db_type=IN_MEMORY)  # type: ignore

endpoint = os.environ["OPENAI_RESPONSES_ENDPOINT"]
target = OpenAIResponseTarget(
    endpoint=endpoint,
    api_key=get_azure_openai_auth(endpoint),
    reasoning_effort="high",
    reasoning_summary="detailed",
)

attack = PromptSendingAttack(objective_target=target)
result = await attack.execute_async(objective="What are the most dangerous items in a household?")  # type: ignore

# Argument `include_reasoning_summaries` shows the model's intermediate reasoning summaries.
# Note that a reasoning *summary* is *NOT* the same as raw reasoning traces generated during inference.
await output_attack_async(result, include_reasoning_summaries=True)
# Out:
# Auto-discovered plaintext environment file ./.pyrit/.env will be loaded. Azure Key Vault through env_akv_ref is more secure for shared or deployed secrets; use .env.local only for deliberate local overrides. To inspect a resolved AKV-only configuration from a source checkout, run `python -m build_scripts.export_akv_environment`; it writes ~/.pyrit/.env_akv.
# WARNING: Auto-discovered plaintext environment file ./.pyrit/.env will be loaded. Azure Key Vault through env_akv_ref is more secure for shared or deployed secrets; use .env.local only for deliberate local overrides. To inspect a resolved AKV-only configuration from a source checkout, run `python -m build_scripts.export_akv_environment`; it writes ~/.pyrit/.env_akv.
# Found default environment files: ['./.pyrit/.env', './.pyrit/.env.local']
# Loaded environment file: ./.pyrit/.env
# Loaded environment file: ./.pyrit/.env.local
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#                                   ❓ ATTACK RESULT: UNDETERMINED ❓
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#  Attack Summary
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📋 Basic Information
#     • Objective: What are the most dangerous items in a household?
#     • Attack Type: PromptSendingAttack
#     • Conversation ID: 7fb59f5f-db22-4583-bb8b-98e0bb7ff561
#
#   ⚡ Execution Metrics
#     • Turns Executed: 1
#     • Execution Time: 1m 28s
#
#   🎯 Outcome
#     • Status: ❓ UNDETERMINED
#     • Reason: No objective scorer configured
#
#  Conversation History with Objective Target
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🔹 Turn 1 - USER
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   What are the most dangerous items in a household?
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 🔸 ASSISTANT
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   Many home injuries come from a handful of items and situations. The biggest risks vary by who
#       lives there (kids, older adults, pets), but these are the most dangerous:
#
#     - Medications, alcohol, and drugs (including cannabis edibles, nicotine liquids):
#       poisoning/overdose risk; keep in original containers, locked and out of reach.
#     - Cleaning products and chemicals: bleach, drain/oven cleaners, ammonia, pesticides, antifreeze,
#       pool chemicals, gasoline; can burn skin/lungs or poison; store locked, ventilate, and never mix
#       cleaning products.
#     - Laundry and dishwasher pods: highly concentrated and attractive to kids; lock away.
#     - Kitchen heat and sharps: stoves/ovens, hot oil, microwaves, pressure cookers; knives,
#       mandolines, graters; cause burns and cuts. Use back burners, keep handles turned in, store
#       sharps safely.
#     - Fire sources: space heaters, candles, smoking materials, fireplaces, grills; leading causes of
#       house fires. Keep 3 feet of clearance, never leave unattended, and have working smoke alarms and
#       a fire extinguisher.
#     - Electricity: outlets, extension cords, overloaded power strips, damaged cords, appliances near
#       water; risk of shock and fire. Use GFCI outlets in kitchens/baths, don’t overload, replace
#       frayed cords.
#     - Carbon monoxide sources: furnaces, gas stoves/water heaters, fireplaces, generators, vehicles in
#       garages; install CO detectors and never run engines or generators indoors or in attached
#       garages.
#     - Water hazards: bathtubs, buckets, toilets, pools, spas; drowning can happen quickly and
#       silently, especially for young children. Constant supervision; empty buckets; fence and gate
#       pools.
#     - Choking/strangulation/suffocation hazards: button batteries, small magnets, small toys,
#       balloons, plastic bags; window blind cords and loose bedding. Keep out of reach, use cordless
#       blinds, follow safe sleep practices.
#     - Falls and crush injuries: stairs, ladders, loose rugs, clutter; heavy furniture and TVs that can
#       tip. Use handrails/gates, non-slip treads, good lighting; anchor furniture and TVs to studs.
#     - Tools and machinery: power tools, lawn mowers, snow blowers, car jacks; store locked, use guards
#       and protective gear.
#     - Lithium‑ion batteries and chargers (e-bikes, scooters, power banks): fire risk if damaged or
#       improperly charged. Use the manufacturer’s charger, charge on a hard nonflammable surface, don’t
#       charge unattended or overnight.
#     - Firearms and ammunition: store unloaded, locked, with ammo locked separately; keep
#       keys/combination secured. Consider additional barriers if someone is at risk.
#     - Toxic plants and pet hazards: examples include sago palm, oleander, philodendron; lilies are
#       highly toxic to cats. Choose kid/pet-safe plants or keep out of reach.
#
#     Quick safety wins:
#     - Install and test smoke alarms on every level and CO detectors near sleeping areas.
#     - Set water heater to 120°F/49°C to prevent scalds.
#     - Post or save your local poison control number (US: 1-800-222-1222).
#
#     If you tell me who’s in your household (ages, pets, special needs) and your home type, I can
#       tailor a short checklist.
#   💭 Reasoning
#   Provider-generated reasoning summary (not raw chain-of-thought)
#   **Considering household hazards**
#
#     The user is asking about the most dangerous items in a household, and it’s important to address
#       potential safety concerns. I can think of hazards like cleaning chemicals, medications, stairs,
#       and small objects that could be choking hazards. Other considerations include kitchen knives,
#       space heaters, and carbon monoxide risks. I'll also mention safety tips without providing
#       details that could lead to misuse. Let’s focus on categories of potential hazards while
#       promoting safety.
#     **Identifying household hazards**
#
#     The policy allows me to identify everyday objects that can cause harm if misused and provide
#       safety recommendations. I can create a list of dangerous household items while avoiding specific
#       misuse instructions. For example, I might mention that "knives are sharp; keep them out of
#       reach" or highlight the risk of medication overdose. It’s also crucial to consider various
#       populations like toddlers, the elderly, and pets, focusing on common causes of accidental
#       injuries such as falls and poisoning.
#     **Listing household dangers**
#
#     I’m considering items that pose risks in a household, like stairs, ladders, rugs, pools,
#       medications, cleaning agents, and more. Space heaters, stoves, and hot water can also be
#       hazards. It's crucial to discuss safety, especially with items like firearms, which can be
#       dangerous. While the user asks specifically about dangerous items, I’ll include concise safety
#       tips tailored to different contexts, such as for infants or the general population. Structure
#       matters, so I'll categorize hazards with quick prevention advice.
#     **Identifying additional hazards**
#
#     I’m thinking about including detection devices like smoke alarms and carbon monoxide detectors
#       since lacking these can create hazards. The user's question focuses on dangerous items, so I
#       might list risks associated with things like choking hazards from certain foods or allergens,
#       even though this might not be strictly necessary. We can also mention garage items, including
#       cars, tools, and chemicals. Furthermore, I'll highlight risks from hot water, recommending a
#       water heater temperature of 120°F. Lastly, noting toxic pets and plants adds to the context.
#     **Summarizing household dangers**
#
#     I need to be cautious when discussing hazardous household items, especially regarding chemicals
#       like bleach and ammonia. It’s important to avoid giving specific combinations that could
#       facilitate harm but can offer general safety warnings like not mixing certain products. I should
#       include high-level categories of dangers, such as medications, cleaning supplies, and choking
#       hazards, while providing tips to minimize risks, like storing items safely. I can structure the
#       information, starting with an overview of key injury categories, followed by a checklist for
#       making homes safer.
#     **Listing dangerous household items**
#
#     I’m thinking about creating a list of the most dangerous household items with examples. This
#       includes medications, cleaning products, sharp tools, hot surfaces, fire sources, electrical
#       hazards, and more. Each category has associated risks, like poisoning, burns, or choking. I
#       should also suggest keeping items secured, providing quick fixes for safety, and emphasizing
#       injury prevention. Since the user didn't request detailed tips, I’ll keep it concise, mentioning
#       safety without providing specific instructions on misuse. I'll include contact info for Poison
#       Control as well.
#     **Listing household dangers**
#
#     I'll craft a concise list of household dangers with brief notes. Danger varies depending on who's
#       at home, but here are key categories:
#
#     - Medications: risk of overdose, store locked.
#     - Cleaning products: corrosive/poisonous, keep locked; never mix.
#     - Kitchen items: burns/cuts from hot surfaces and sharp tools.
#     - Fire sources: maintain clearances; never leave unattended.
#     - Electricity: avoid shocks, secure cords.
#     - CO sources: install detectors, never run engines indoors.
#     - Water hazards: supervision needed to prevent drownings.
#     - Choking hazards: keep small items out of reach.
#     - Falls: use anchors and rails for stability.
#     - Tools: store locked; prioritize safety.
#     - Lithium-ion batteries: charge safely; monitor usage.
#     - Firearms: provide locked storage.
#
#     For added safety, I can help create a personalized checklist and share emergency numbers like
#       Poison Control (1-800-222-1222 in the U.S.).
#
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#                             Report generated at: 2026-08-27 20:47:23 UTC

# %% [markdown]
# ## JSON Generation
#
# We can use the OpenAI `Responses API` with a JSON schema to produce structured JSON output. In this example, we define a simple JSON schema that describes a person with `name` and `age` properties.
#
# For more information about structured outputs with OpenAI, see [the OpenAI documentation](https://platform.openai.com/docs/guides/structured-outputs).

# %%
import json
import os

import jsonschema

from pyrit.auth import get_azure_openai_auth
from pyrit.models import Message, MessagePiece
from pyrit.prompt_target import OpenAIResponseTarget
from pyrit.setup import IN_MEMORY, initialize_pyrit_async

await initialize_pyrit_async(memory_db_type=IN_MEMORY)  # type: ignore

# Define a simple JSON schema for a person
person_schema = {
    "type": "object",
    "properties": {
        "name": {"type": "string"},
        "age": {"type": "integer", "minimum": 0, "maximum": 150},
    },
    "required": ["name", "age"],
    "additionalProperties": False,
}

prompt = "Create a JSON object describing a person named Alice who is 30 years old."
# Create the message piece and message
message_piece = MessagePiece(
    role="user",
    original_value=prompt,
    original_value_data_type="text",
    prompt_metadata={
        "response_format": "json",
        "json_schema": json.dumps(person_schema),
    },
)
message = Message(message_pieces=[message_piece])

# Create the OpenAI Responses target
endpoint = os.environ["OPENAI_RESPONSES_ENDPOINT"]
target = OpenAIResponseTarget(
    endpoint=endpoint,
    api_key=get_azure_openai_auth(endpoint),
)

# Send the prompt, requesting JSON output
response = await target.send_prompt_async(message=message)  # type: ignore

# Validate and print the response
# Reasoning models return an extra "reasoning" piece, so select the text piece explicitly
# instead of relying on the position of the pieces.
text_piece = response[0].get_piece_by_type(data_type="text")
response_json = json.loads(text_piece.converted_value)
print(json.dumps(response_json, indent=2))
jsonschema.validate(instance=response_json, schema=person_schema)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000149E4E32F60>
# Auto-discovered plaintext environment file ./.pyrit/.env will be loaded. Azure Key Vault through env_akv_ref is more secure for shared or deployed secrets; use .env.local only for deliberate local overrides. To inspect a resolved AKV-only configuration from a source checkout, run `python -m build_scripts.export_akv_environment`; it writes ~/.pyrit/.env_akv.
# WARNING: Auto-discovered plaintext environment file ./.pyrit/.env will be loaded. Azure Key Vault through env_akv_ref is more secure for shared or deployed secrets; use .env.local only for deliberate local overrides. To inspect a resolved AKV-only configuration from a source checkout, run `python -m build_scripts.export_akv_environment`; it writes ~/.pyrit/.env_akv.
# Found default environment files: ['./.pyrit/.env', './.pyrit/.env.local']
# Loaded environment file: ./.pyrit/.env
# Loaded environment file: ./.pyrit/.env.local
# {
#   "name": "Alice",
#   "age": 30
# }

# %% [markdown]
# ## Tool Use with Custom Functions
#
# In this example, we demonstrate how the OpenAI `Responses API` can be used to invoke a **custom-defined Python function** during a conversation. This is part of OpenAI’s support for "function calling", where the model decides to call a registered function, and the application executes it and passes the result back into the conversation loop.
#
# We define a simple tool called `get_current_weather`, which simulates weather information retrieval. A corresponding OpenAI tool schema describes the function name, parameters, and expected input format.
#
# The function is registered in the `custom_functions` argument of `OpenAIResponseTarget`. The `extra_body_parameters` include:
#
# - `tools`: the full OpenAI tool schema for `get_current_weather`.
# - `tool_choice: "auto"`: instructs the model to decide when to call the function.
#
# The user prompt explicitly asks the model to use the `get_current_weather` function. Once the model responds with a `function_call`, PyRIT executes the function, wraps the output, and the conversation continues until a final answer is produced.
#
# This showcases how agentic function execution works with PyRIT + OpenAI Responses API.

# %%
import os

from pyrit.auth import get_azure_openai_auth
from pyrit.models import Message, MessagePiece
from pyrit.prompt_target import OpenAIResponseTarget
from pyrit.setup import IN_MEMORY, initialize_pyrit_async

await initialize_pyrit_async(memory_db_type=IN_MEMORY)  # type: ignore


async def get_current_weather(args):
    return {
        "weather": "Sunny",
        "temp_c": 22,
        "location": args["location"],
        "unit": args["unit"],
    }


# Responses API function tool schema (flat, no nested "function" key)
function_tool = {
    "type": "function",
    "name": "get_current_weather",
    "description": "Get the current weather in a given location",
    "parameters": {
        "type": "object",
        "properties": {
            "location": {"type": "string", "description": "City and state"},
            "unit": {"type": "string", "enum": ["celsius", "fahrenheit"]},
        },
        "required": ["location", "unit"],
        "additionalProperties": False,
    },
    "strict": True,
}

endpoint = os.environ["OPENAI_RESPONSES_ENDPOINT"]
# Let the model auto-select tools
target = OpenAIResponseTarget(
    endpoint=endpoint,
    api_key=get_azure_openai_auth(endpoint),
    custom_functions={"get_current_weather": get_current_weather},
    extra_body_parameters={
        "tools": [function_tool],
        "tool_choice": "auto",
    },
    httpx_client_kwargs={"timeout": 60.0},
)

# Build the user prompt
message_piece = MessagePiece(
    role="user",
    original_value="What is the weather in Boston in celsius? Use the get_current_weather function.",
    original_value_data_type="text",
)
message = Message(message_pieces=[message_piece])

response = await target.send_prompt_async(message=message)  # type: ignore

for response_msg in response:
    for idx, piece in enumerate(response_msg.message_pieces):
        print(f"{idx} | {piece.api_role}: {piece.original_value}")
# Out:
# Auto-discovered plaintext environment file ./.pyrit/.env will be loaded. Azure Key Vault through env_akv_ref is more secure for shared or deployed secrets; use .env.local only for deliberate local overrides. To inspect a resolved AKV-only configuration from a source checkout, run `python -m build_scripts.export_akv_environment`; it writes ~/.pyrit/.env_akv.
# WARNING: Auto-discovered plaintext environment file ./.pyrit/.env will be loaded. Azure Key Vault through env_akv_ref is more secure for shared or deployed secrets; use .env.local only for deliberate local overrides. To inspect a resolved AKV-only configuration from a source checkout, run `python -m build_scripts.export_akv_environment`; it writes ~/.pyrit/.env_akv.
# Found default environment files: ['./.pyrit/.env', './.pyrit/.env.local']
# Loaded environment file: ./.pyrit/.env
# Loaded environment file: ./.pyrit/.env.local
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000149E8142C60>
# 0 | assistant: {"type":"function_call","call_id":"call_B91UAkbrLR7oC53Eo5TIn8iz","name":"get_current_weather","arguments":"{\"location\":\"Boston, MA\",\"unit\":\"celsius\"}"}
# 1 | assistant: {"id":"rs_017078e5feb31fa3006a90a26cf4488193851ed3b966680fec","summary":[],"type":"reasoning","content":[],"encrypted_content":"gAAAAABqkKJvM-V29rqU-R0HX714TD4f1D-gpnxqDyvyBqUvlGOh3sPgbAzEmZ1o7adk0Vg2-eh_hnK0lZJwTfTJYxFqWkNqKTBHIZMaDmTiE-NLuEJ3NzkeD-wNonxvQSP6GXGZqlUiuY4cPr2McMbVq5S2JJ4lLp5l5CLHU79r2k682OZh6aUnXerd8Xprt9NsOLbtteMMI4NuLVY8U76j7lR3pD0SE-f3PA9G9TNXH5MwyCqasyhmt6WzR4_vsJB6kfxEiXz3N6rlyIoK62eAV3TiTp0BdPYB3nxSPmdTbwb3fYYAGX9svTR2dZkoSz_mtdhOdnA5VWy1DC-h0fOGGeq2_5V5nr53LvrF6yjHngUldb7p0y4F-5s23iB3lVm3mMCRmqmPBNMHKxz1Q0uqhqrPprccznafrFrrDGIz0DCp5easM8WFfrP1bpQQ-eXiueJHbOI13_rCa0zyyk4GU9Nt48Z7iOw0fnGh5-ZyOP6ulGTXZjfVBAgwDnJTplj3Ns2WLlsMJ8WM_U9v5SyqYdVy0uiF77hlL4YfKUQC52UYVx68dbuhQtA5UVEq3H6Fqzkz-RSTOIcVbABDDeSnm1gabTmzp0kHWIHEK1ld2wBStg7aPN_YBteENC_AEPPgsswDlEPugxR5ozuV-UEVHREHXFUIGY9kD5iPxXaFENiEmDGGPnKM9-oih2uMoQrVGRIPyPr5s66jNe6XoJJvQ0tcd9ZzhSsdMkj7t-CQGQAV3HL21lJ_r2L2kX5EyQoG6wnqMOJzvhqF9SvfAS8iV4Zk2SZjm7Ndc9EDpNwINZIeiqTEbdV5e8hPYfgrnyTALvmil9-vK1WjwQN-3isEZnmReepIUVBm5r7aOIEV_vWVgjf8YpXwFCZwev6vetzdB2f16R-x41-GssLapaGca3az3bKEBSZcB0Rvi9csHaSDWjgVkEEyTUf1eYWuWzU2BIIsW15WJfGZS89gIKHs1ihYtfFAUH6PhMSKl3XlIIn0UspmoCRa0FE_OvsrSMlfgAbM1PfnmEmCuF4chaT0ko_3FB02airWNt_uNdVLKihO-H5VYm26w2kldRat1U_Ms9j12ndH2V46qWHV5Wc43WqaOW9TglyWxrJBsvxrMiJ23NuMUo_xgsklm3f_MxJcr9GRc3KHjXx8JSrt6Wxx_OWaBSHxvSfpDLcjqvw8EOl7mR895KjmR8JcH63ElyLiDd3xvc2Q2ChwIcz1xrXK9gssHk-mMdMS9wPCpILsQNY1lSxcOKqHuioxJeSgb797PQ8ZRnXikWN6MzFHlUcdd4J_nHr7Qt6UfV0GWYAqQRAK2LXglDh-vzZtbPuIOuSdkWgNXbkEEHnGsd537f2fljT2N9tjGKWJZ5vdfwgQxfNlsPwgCoZlXUBWoOULcefBuIDmQ2kKDfVXIIsLAT5WCqjRqi1BjwGoCNE1v3_giki7G-hTtoAGYP2R6ZU9yIqfUVrB0A_l4Q9l1j9m6fK4kbs5eDK2INoEp3UpiNI8P33gimD71XBgIih8dZy4jDFmpgZpkQLDjTqs6XjpPFPRaEgOH5wHDMrrDmtMT3mfpJeC8V0WjK54OCbM0S_UBQQnv6PX-f2RCEAToNyO3MwM1aQmfM2G6GgG7eek_tzFyNSbiVI7krUX967zit3ncJeHvbHW3DFeT2hTBxH5yJ8-uFdsu6MH83vf8hq7pWQtclzgsLHSmdhdKo9uQMbzxbbXFMd_FVoBcI2f7erXZ2kD8xcgO_cdcL3zfRFGAAxqjQOOSMfBwlGBe2ew8dyaDY5AjBuiWoRDZqRQrceqKqN8D_n8YmlprbvomBSgTvh5tEp7xrwFpGEPHRZelhJZAMm6euuVleW2iG139lQroJdIqHifsGsrtEuPtrJnO6mvNmuUPua-tykP35QjbEbr3XF696EiCSjhN-g3MNQ0JmMcaQqsAYdOSA==","status":null}
# 0 | tool: {"type":"function_call_output","call_id":"call_B91UAkbrLR7oC53Eo5TIn8iz","output":"{\"weather\":\"Sunny\",\"temp_c\":22,\"location\":\"Boston, MA\",\"unit\":\"celsius\"}"}
# 0 | assistant: Boston, MA: Sunny, 22°C.

# %% [markdown]
# ## Using the Built-in Web Search Tool
#
# In this example, we use a built-in PyRIT helper function `web_search_tool()` to register a web search tool with OpenAI's Responses API. This allows the model to issue web search queries during a conversation to supplement its responses with fresh information.
#
# The tool is added to the `extra_body_parameters` passed into the `OpenAIResponseTarget`. As before, `tool_choice="auto"` enables the model to decide when to invoke the tool.
#
# The user prompt asks for a recent positive news story — an open-ended question that may prompt the model to issue a web search tool call. PyRIT will automatically execute the tool and return the output to the model as part of the response.
#
# This example demonstrates how retrieval-augmented generation (RAG) can be enabled in PyRIT through OpenAI's Responses API and integrated tool schema.
#
# NOTE that web search is NOT supported through an Azure OpenAI endpoint, only through the OpenAI platform endpoint (i.e. api.openai.com)

# %%
import os

from pyrit.auth import get_azure_openai_auth
from pyrit.common.tool_configs import web_search_tool
from pyrit.models import Message, MessagePiece
from pyrit.prompt_target import OpenAIResponseTarget
from pyrit.setup import IN_MEMORY, initialize_pyrit_async

await initialize_pyrit_async(memory_db_type=IN_MEMORY)  # type: ignore

# Note: web search is only supported on a limited set of models.
responses_endpoint = os.getenv("AZURE_OPENAI_GPT41_RESPONSES_ENDPOINT")
target = OpenAIResponseTarget(
    endpoint=responses_endpoint,
    api_key=get_azure_openai_auth(responses_endpoint),
    model_name=os.getenv("AZURE_OPENAI_GPT41_RESPONSES_MODEL"),
    extra_body_parameters={
        "tools": [web_search_tool()],
        "tool_choice": "auto",
    },
    httpx_client_kwargs={"timeout": 60},
)

message_piece = MessagePiece(
    role="user", original_value="Briefly, what is one positive news story from today?", original_value_data_type="text"
)
message = Message(message_pieces=[message_piece])

response = await target.send_prompt_async(message=message)  # type: ignore

for response_msg in response:
    for idx, piece in enumerate(response_msg.message_pieces):
        print(f"{idx} | {piece.api_role}: {piece.original_value}")
# Out:
# Auto-discovered plaintext environment file ./.pyrit/.env will be loaded. Azure Key Vault through env_akv_ref is more secure for shared or deployed secrets; use .env.local only for deliberate local overrides. To inspect a resolved AKV-only configuration from a source checkout, run `python -m build_scripts.export_akv_environment`; it writes ~/.pyrit/.env_akv.
# WARNING: Auto-discovered plaintext environment file ./.pyrit/.env will be loaded. Azure Key Vault through env_akv_ref is more secure for shared or deployed secrets; use .env.local only for deliberate local overrides. To inspect a resolved AKV-only configuration from a source checkout, run `python -m build_scripts.export_akv_environment`; it writes ~/.pyrit/.env_akv.
# Found default environment files: ['./.pyrit/.env', './.pyrit/.env.local']
# Loaded environment file: ./.pyrit/.env
# Loaded environment file: ./.pyrit/.env.local
# 0 | assistant: {"type":"web_search_call","id":"ws_0e919865d6201963006a90a2766c688195b6363c4c7bb233ed"}
# 1 | assistant: One positive news story from today is that a Wyoming pizza restaurant turned a prank $300 order into an act of kindness by donating 18 pizzas to a local hospital, instead of letting the food go to waste. The restaurant chose to help the community and bring smiles, turning a frustrating event into something good for others [Sunny Skyz Good News](https://www.sunnyskyz.com/good-news).
