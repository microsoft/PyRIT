# %% [markdown]
# # SQLite Memory
#
# The memory SQLite database can be thought of as a normalized source of truth. The memory module is the primary way PyRIT keeps track of requests and responses to targets and scores. Most of this is done automatically. All Prompt Targets write to memory for later retrieval. All scorers also write to memory when scoring.
#
# The schema is found in `memory_models.py` and can be programmatically viewed as follows

# %%
from pyrit.memory import SQLiteMemory

# Use in-memory database to avoid file corruption issues
memory = SQLiteMemory(db_path=":memory:")
memory.print_schema()
# Out:
# [pyrit:alembic] No new upgrade operations detected.
# Database Schema:
# ================
#
# Table: PromptMemoryEntries
# --------------------------
#   id: CHAR(32) NOT NULL
#   role: VARCHAR NOT NULL
#   conversation_id: VARCHAR NOT NULL
#   sequence: INTEGER NOT NULL
#   timestamp: DATETIME NOT NULL
#   prompt_metadata: JSON NOT NULL
#   converter_identifiers: JSON NULL
#   response_error: VARCHAR NULL
#   original_value_data_type: VARCHAR NOT NULL
#   original_value: VARCHAR NOT NULL
#   original_value_sha256: VARCHAR NULL
#   converted_value_data_type: VARCHAR NOT NULL
#   converted_value: VARCHAR NULL
#   converted_value_sha256: VARCHAR NULL
#   original_prompt_id: CHAR(32) NOT NULL
#   pyrit_version: VARCHAR NULL
#
# Table: AdditionalInitializers
# -----------------------------
#   id: VARCHAR(36) NOT NULL
#   initializer_name: VARCHAR(64) NOT NULL
#   parameters: JSON NULL
#   order_index: INTEGER NULL
#
# Table: TargetIdentifiers
# ------------------------
#   endpoint: VARCHAR NULL
#   model_name: VARCHAR NULL
#   underlying_model_name: VARCHAR NULL
#   temperature: FLOAT NULL
#   top_p: FLOAT NULL
#   max_requests_per_minute: INTEGER NULL
#   supported_auth_modes: JSON NULL
#   hash: VARCHAR(64) NOT NULL
#   class_name: VARCHAR NULL
#   class_module: VARCHAR NULL
#   identifier_json: JSON NULL
#   pyrit_version: VARCHAR NULL
#
# Table: TargetIdentifierChildren
# -------------------------------
#   parent_hash: VARCHAR(64) NOT NULL
#   position: INTEGER NOT NULL
#   child_hash: VARCHAR(64) NOT NULL
#
# Table: ConverterIdentifiers
# ---------------------------
#   supported_input_types: JSON NULL
#   supported_output_types: JSON NULL
#   converter_target_hash: VARCHAR(64) NULL
#   sub_converter_hash: VARCHAR(64) NULL
#   hash: VARCHAR(64) NOT NULL
#   class_name: VARCHAR NULL
#   class_module: VARCHAR NULL
#   identifier_json: JSON NULL
#   pyrit_version: VARCHAR NULL
#
# Table: PromptConverterIdentifiers
# ---------------------------------
#   prompt_memory_entry_id: CHAR(32) NOT NULL
#   position: INTEGER NOT NULL
#   converter_identifier_hash: VARCHAR(64) NOT NULL
#
# Table: ScorerIdentifiers
# ------------------------
#   scorer_type: VARCHAR NULL
#   score_aggregator: VARCHAR NULL
#   prompt_target_hash: VARCHAR(64) NULL
#   hash: VARCHAR(64) NOT NULL
#   class_name: VARCHAR NULL
#   class_module: VARCHAR NULL
#   identifier_json: JSON NULL
#   pyrit_version: VARCHAR NULL
#
# Table: ScorerIdentifierChildren
# -------------------------------
#   parent_hash: VARCHAR(64) NOT NULL
#   position: INTEGER NOT NULL
#   child_hash: VARCHAR(64) NOT NULL
#
# Table: ScenarioIdentifiers
# --------------------------
#   version: INTEGER NULL
#   techniques: JSON NULL
#   datasets: JSON NULL
#   objective_target_hash: VARCHAR(64) NULL
#   objective_scorer_hash: VARCHAR(64) NULL
#   hash: VARCHAR(64) NOT NULL
#   class_name: VARCHAR NULL
#   class_module: VARCHAR NULL
#   identifier_json: JSON NULL
#   pyrit_version: VARCHAR NULL
#
# Table: SeedIdentifiers
# ----------------------
#   value: VARCHAR NULL
#   value_sha256: VARCHAR NULL
#   data_type: VARCHAR NULL
#   dataset_name: VARCHAR NULL
#   is_general_technique: BOOLEAN NULL
#   hash: VARCHAR(64) NOT NULL
#   class_name: VARCHAR NULL
#   class_module: VARCHAR NULL
#   identifier_json: JSON NULL
#   pyrit_version: VARCHAR NULL
#
# Table: AttackIdentifiers
# ------------------------
#   adversarial_system_prompt: VARCHAR NULL
#   adversarial_seed_prompt: VARCHAR NULL
#   objective_target_hash: VARCHAR(64) NULL
#   adversarial_chat_hash: VARCHAR(64) NULL
#   objective_scorer_hash: VARCHAR(64) NULL
#   hash: VARCHAR(64) NOT NULL
#   class_name: VARCHAR NULL
#   class_module: VARCHAR NULL
#   identifier_json: JSON NULL
#   pyrit_version: VARCHAR NULL
#
# Table: AttackRequestConverterIdentifiers
# ----------------------------------------
#   attack_identifier_hash: VARCHAR(64) NOT NULL
#   position: INTEGER NOT NULL
#   converter_identifier_hash: VARCHAR(64) NOT NULL
#
# Table: AttackResponseConverterIdentifiers
# -----------------------------------------
#   attack_identifier_hash: VARCHAR(64) NOT NULL
#   position: INTEGER NOT NULL
#   converter_identifier_hash: VARCHAR(64) NOT NULL
#
# Table: AttackTechniqueIdentifiers
# ---------------------------------
#   attack_identifier_hash: VARCHAR(64) NULL
#   hash: VARCHAR(64) NOT NULL
#   class_name: VARCHAR NULL
#   class_module: VARCHAR NULL
#   identifier_json: JSON NULL
#   pyrit_version: VARCHAR NULL
#
# Table: AttackTechniqueSeedIdentifiers
# -------------------------------------
#   attack_technique_identifier_hash: VARCHAR(64) NOT NULL
#   position: INTEGER NOT NULL
#   seed_identifier_hash: VARCHAR(64) NOT NULL
#
# Table: AtomicAttackIdentifiers
# ------------------------------
#   attack_technique_identifier_hash: VARCHAR(64) NULL
#   hash: VARCHAR(64) NOT NULL
#   class_name: VARCHAR NULL
#   class_module: VARCHAR NULL
#   identifier_json: JSON NULL
#   pyrit_version: VARCHAR NULL
#
# Table: AtomicAttackSeedIdentifiers
# ----------------------------------
#   atomic_attack_identifier_hash: VARCHAR(64) NOT NULL
#   position: INTEGER NOT NULL
#   seed_identifier_hash: VARCHAR(64) NOT NULL
#
# Table: Conversations
# --------------------
#   conversation_id: VARCHAR(36) NOT NULL
#   target_identifier: JSON NULL
#   target_identifier_hash: VARCHAR(64) NULL
#   retries: JSON NULL
#   pyrit_version: VARCHAR NULL
#
# Table: EmbeddingData
# --------------------
#   id: CHAR(32) NOT NULL
#   embedding: ARRAY NULL
#   embedding_type_name: VARCHAR NULL
#
# Table: ScorableContentEntries
# -----------------------------
#   id: CHAR(32) NOT NULL
#   value: VARCHAR NOT NULL
#   value_sha256: VARCHAR(64) NOT NULL
#   data_type: VARCHAR(32) NOT NULL
#   timestamp: DATETIME NOT NULL
#
# Table: ScoreEntries
# -------------------
#   id: CHAR(32) NOT NULL
#   score_value: VARCHAR NULL
#   score_value_description: VARCHAR NULL
#   status: VARCHAR(16) NOT NULL DEFAULT ScalarElementColumnDefault('complete')
#   score_type: VARCHAR NOT NULL
#   score_category: JSON NULL
#   score_rationale: VARCHAR NULL
#   score_metadata: JSON NOT NULL
#   scorer_class_identifier: JSON NOT NULL
#   scorable: JSON NULL
#   scorable_content_id: CHAR(32) NULL
#   scorer_identifier_hash: VARCHAR(64) NULL
#   prompt_request_response_id: CHAR(32) NULL
#   timestamp: DATETIME NOT NULL
#   objective: VARCHAR NULL
#   pyrit_version: VARCHAR NULL
#
# Table: SeedPromptEntries
# ------------------------
#   id: CHAR(32) NOT NULL
#   value: VARCHAR NOT NULL
#   value_sha256: VARCHAR NULL
#   data_type: VARCHAR NOT NULL
#   name: VARCHAR NULL
#   dataset_name: VARCHAR NULL
#   harm_categories: JSON NULL
#   description: VARCHAR NULL
#   authors: JSON NULL
#   groups: JSON NULL
#   source: VARCHAR NULL
#   date_added: DATETIME NOT NULL
#   added_by: VARCHAR NOT NULL
#   prompt_metadata: JSON NULL
#   parameters: JSON NULL
#   prompt_group_id: CHAR(32) NULL
#   sequence: INTEGER NULL
#   role: VARCHAR NULL
#   seed_type: VARCHAR NOT NULL DEFAULT ScalarElementColumnDefault('prompt')
#
# Table: AttackResultEntries
# --------------------------
#   id: CHAR(32) NOT NULL
#   conversation_id: VARCHAR(36) NOT NULL
#   objective: VARCHAR NOT NULL
#   atomic_attack_identifier: JSON NULL
#   atomic_attack_identifier_hash: VARCHAR(64) NULL
#   objective_sha256: VARCHAR NULL
#   last_response_id: CHAR(32) NULL
#   last_score_id: CHAR(32) NULL
#   executed_turns: INTEGER NOT NULL DEFAULT ScalarElementColumnDefault(0)
#   execution_time_ms: INTEGER NOT NULL DEFAULT ScalarElementColumnDefault(0)
#   outcome: VARCHAR NOT NULL DEFAULT ScalarElementColumnDefault('undetermined')
#   outcome_reason: VARCHAR NULL
#   attack_metadata: JSON NULL
#   labels: JSON NULL
#   targeted_harm_categories: JSON NULL
#   pruned_conversation_ids: JSON NULL
#   adversarial_chat_conversation_ids: JSON NULL
#   timestamp: DATETIME NOT NULL
#   pyrit_version: VARCHAR NULL
#   error_message: VARCHAR NULL
#   error_type: VARCHAR NULL
#   error_traceback: VARCHAR NULL
#   retry_events_json: VARCHAR NULL
#   total_retries: INTEGER NULL DEFAULT ScalarElementColumnDefault(0)
#   attribution_parent_id: CHAR(32) NULL
#   attribution_data: JSON NULL
#
# Table: ScenarioResultEntries
# ----------------------------
#   id: CHAR(32) NOT NULL
#   scenario_name: VARCHAR NOT NULL
#   scenario_description: VARCHAR NULL
#   scenario_version: INTEGER NOT NULL DEFAULT ScalarElementColumnDefault(1)
#   pyrit_version: VARCHAR NOT NULL
#   scenario_identifier: JSON NOT NULL
#   scenario_identifier_hash: VARCHAR(64) NULL
#   objective_target_identifier: JSON NOT NULL
#   objective_scorer_identifier: JSON NULL
#   scenario_run_state: VARCHAR NOT NULL DEFAULT ScalarElementColumnDefault('CREATED')
#   display_group_map_json: VARCHAR NULL
#   labels: JSON NULL
#   number_tries: INTEGER NOT NULL DEFAULT ScalarElementColumnDefault(0)
#   completion_time: DATETIME NOT NULL
#   timestamp: DATETIME NOT NULL
#   error_message: VARCHAR NULL
#   error_type: VARCHAR NULL
#   scenario_metadata: JSON NULL
